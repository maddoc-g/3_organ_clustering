# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.signal import find_peaks, welch
import pandas as pd
from pandas.plotting import parallel_coordinates
import sklearn
from sklearn.cluster import KMeans
from lib.readwav import *

# %% [markdown]
# # Classificazione di note prodotte da un organo

# %%
# Questa cella è un primo esempio di lettura di segnale audio, al momento commentata per alleggerire l'esecuzione.


# Per leggere i segnali audio, useremo la funzione readwav già precedentemente scritta e fornitaci.
# Questa funzione si trova nel file readwav.py all'interno della cartella lib. Si usa come segue:
#filename = "./wav_files/note_104.wav"
#rate, note = readwav(filename)
# Nella maniera in cui è implementata, readwav restituisce due cose: un float contenente il sampling rate del segnale,
# e un array contenente i dati veri e propri, ossia l'intensità del segnale nel tempo.
# In particolare, la funzione tratta ugualmente wav in 8bit oppure 24bit, e l'array ha una sola colonna se il segnale è mono,
# oppure due colonne se il segnale è stereo (noi useremo sempre uno solo dei due canali).

# Per trattare dunque l'array di dati, innanzitutto generiamo i time step corrispondenti:
#time = np.linspace(0, note.shape[0], note.shape[0], endpoint = False) # Fin qui, time è solo un indice contatore,
#time /= rate
# mentre così time contiene ora il tempo fisico.

# Possiamo plottare il segnale per farci un'idea di com'è fatto. Nel primo pannello rappresentiamo tutto il segnale,
# mentre nel secondo una porzione zoomata al centro per riuscire a vedere i singoli periodi.
#figure, axes = plt.subplots(2, 1, figsize=(12, 7))
#ax = axes[0]
#ax.plot(time, note[:,0])
#ax = axes[1]
#ax.plot(time, note[:,0])
#ax.set_xlim(3.0, 3.01)
#plt.tight_layout()
#plt.show()

# %%
# Questa cella verifica al volo le distribuzioni di sampling rates e durate dei segnali. Commentato per alleggerire l'esecuzione.


# Prima li leggiamo tutti quanti:
#all_rates = []
#all_lengths = []
#for i in range(280): # Vediamo manualmente che nella cartella ci sono 280 file in totale
#    filename = "./wav_files/note_{}.wav".format(i+1)
#    rate, note = readwav(filename)
#    time = np.linspace(0, note.shape[0], note.shape[0], endpoint = False) / rate
#    all_rates.append(rate)
#    all_lengths.append(np.max(time))
#
# E poi li grafichiamo:
#figure, axes = plt.subplots(1, 2, figsize=(12, 5))
#ax = axes[0]
#ax.hist(all_rates, bins=np.linspace(40000.0, 50000.0, 41))
#ax.set_xlabel("Frequenze di campionamento [Hz]")
#ax.set_ylabel("Conteggio")
#ax.set_xlim(40000.0, 50000.0)
##ax.yaxis.set_label_coords(-0.1, 0.5)
#ax = axes[1]
#ax.hist(all_lengths, bins=50)
#ax.set_xlabel("Durata del segnale [s]")
#ax.set_ylabel("Conteggio")
#ax.set_xlim(4.0, 12.0)
##ax.yaxis.set_label_coords(-0.1, 0.5)
#plt.tight_layout()
#plt.show()

# Vedremo dai due grafici come le durate vanno circa dai 4s ai 12s (estremi esclusi), mentre i sampling rates sono TUTTI 48khz.

# %%
# Questa cella è per la verifica manuale di tutti gli attack e decay, ovviamente da lasciare commentata.


# L'idea è estremamente semplice: tagliamo il primo X% a tutti i segnali per togliere gli attack, e l'ultimo Y%
# a tutti i segnali per togliere i decay. Non è affatto elegante, ma è veloce, semplice e funziona.

#for i in range(280):
#    filename = "./wav_files/note_{}.wav".format(i+1)
#    rate, note = readwav(filename)
#    time = np.linspace(0, note.shape[0], note.shape[0], endpoint = False) / rate
#    first_15 = time[0] + 0.15 * (time[-1] - time[0])
#    last_5 = time[0] + 0.95 * (time[-1] - time[0])
#    plt.figure(figsize=(12,5))
#    plt.plot(time, note[:,0])
#    plt.title("Nota numero {}".format(i+1))
#    plt.axvline(x = first_15, color = "r", linestyle = "--")
#    plt.axvline(x = last_5, color = "r", linestyle = "--")
#    plt.show()

# Quello che si può osservare è 15% è esattamente la porzione iniziale da tagliare minima necessaria a coprire TUTTI gli attack.
# La maggior parte dei segnali non sembra avere alcun decay, ma tagliamo l'ultimo 5% per sicurezza.

# %%
# Scegliamo arbitrariamente un file da analizzare e cominciamo.

# Innanzitutto lo leggiamo:
filename = "./wav_files/note_244.wav"
rate, note = readwav(filename)
note = note[:,0] # D'ora in poi presumiamo questo step, che diventa quindi necessario
time = np.linspace(0, note.shape[0], note.shape[0], endpoint = False) / rate

# Poi, creiamo la maschera che tagli in maniera netta il primo 15% e l'ultimo 5%:
first_15 = time[0] + 0.15 * (time[-1] - time[0])
last_5 = time[0] + 0.95 * (time[-1] - time[0])
cut = (time >= first_15) & (time <= last_5)
# Questa maschera è da sovrascrivere ogni volta che leggiamo un nuovo file, dato che in generale hanno lunghezze diverse.
# Ecco come si applica:
note = note[cut]
time = time[cut]

# Se vogliamo possiamo graficare il risultato:
#figure, axes = plt.subplots(2, 1, figsize=(12, 7))
#ax = axes[0]
#ax.plot(time, note)
#ax = axes[1]
#ax.plot(time, note)
#ax.set_xlim(3.0, 3.01)
#plt.tight_layout()
#plt.show()

# %%
# Anche dopo aver tagliato inizio e fine del segnale, poi dovremo comunque applicare una funzione finestra al segnale tagliato.
# Una funzione finestra liscia serve a migliorare i risultati della FFT che faremo dopo; come finestra, scegliamo una campana gaussiana.

gaussian_window = scipy.signal.windows.gaussian(len(note), std = len(note)//6) # Gli strumenti di Scipy lavorano in indici:
# il primo parametro è la larghezza in indici della finestra, il secondo parametro è la deviazione standard in indici della campana.
# Qui in pratica stiamo dicendo di creare una finestra gaussiana larga quanto l'intera durata della nota e tale da arrivare a tre sigma.

# Per applicare la finestra ci basterà moltiplicarla al segnale:
masked_note = note * gaussian_window

# Grafichiamo i risultati per verificare tutto abbia funzionato come previsto:
plt.figure(figsize=(12, 7))
plt.plot(time, masked_note)
plt.xlabel("Tempo [s]")
plt.ylabel("Intensità [a.u.]")
plt.show()
print("\nDurata del sostegno: {:.1f} s\n".format(time[-1]-time[0]))
# Out:
# Durata del sostegno: 4.8 s

# %%
# Questa cella serve a mostrare gli effetti di una finestra più ampia sullo spettro finale. Per ora lasciamo commentato.


# Oltre ad eseguire per la prima volta la FFT del segnale mascherato, vogliamo fare un confronto qualitativo per vedere
# cosa succede a suddetta FFT quando variamo il valore di sigma della funzione finestra:
#decreasing_sigmas = [0.5 * rate,
#                     0.1 * rate,
#                     0.05 * rate,
#                     0.01 * rate]

#figure, axes = plt.subplots(4, 1, figsize=(12, 30))
##figure.subplots_adjust(hspace = 0.35)
#for i in range(4):
#    gaussian_window = scipy.signal.windows.gaussian(len(note), std = int(decreasing_sigmas[i]))
#    masked_note = note * gaussian_window
#    y = scipy.fft.rfft(masked_note)
#    y = np.abs(y)**2
#    x = scipy.fft.rfftfreq(masked_note.shape[0], d=1/rate)
#    ax = axes[i]
#    ax.plot(x, y)
#    ax.set_yscale("log", base=10)
#    #ax.set_xscale("log", base=2)
#    ax.set_xscale("log", base=10)
#    ax.set_title("$\sigma = {}\,$s".format(decreasing_sigmas[i] / rate))
#    ax.set_xlim(2**4, 2**14)
#    ax.set_ylabel("Spettro di potenza [a.u.]")
#    ax.set_xlabel("Frequenza [Hz]")
#    ax.grid(linestyle = ":")
#    #ax.yaxis.set_label_coords(-0.1, 0.5)
##axes[-1].set_xlabel("Frequenza [Hz]")
#plt.show()
# Come possiamo vedere, restringere la sigma ha l'effetto di "diramare" il rumore bianco, senza necessariamente ridurne l'ampiezza.
# Sembra che sigma=0.1s sia un buon compromesso tra risoluzione e rumore, e infatti useremo quella come default d'ora in poi.

# %%
# L'idea di base ora è che se dividiamo l'intero sostegno della nota in vari segmenti, questi in teoria dovrebbero mostrare
# gli stessi picchi, dopotutto la nota suonata è sempre la stessa in ogni segmento. Tuttavia, il rumore bianco di fondo
# è invece ogni volta random, quindi se facciamo la FFT su tutti i segmenti e facciamo la media delle FFT allora
# il rumore bianco dovrebbe semplificarsi, lasciando le armoniche più nitide!

# Fattostà che c'è un metodo di Scipy che fa esattamente questo che abbiamo detto: divide il segnale in segmenti,
# calcola lo spettro di ciascun segmento e restituisce la media di tutti gli spettri. Questo metodo si chiama welch.
# Vediamo ora come si usa, ma prima nota bene una cosa teorica importante: applicare una finestra smooth è ancora necessario,
# e quando dividiamo in segmenti allora la finestra va applicata ad ogni segmento. Per questo motivo, è opportuno che tariamo
# la larghezza della finestra su quella della segmentazione, nel senso che la finestra deve ora essere larga quanto un segmento
# e non quanto l'intero sostegno della nota.

width = (time[-1] - time[0]) / 10 # Definiamo la width della finestra in secondi; sarà anche la taglia dei segmenti.
# Una width fissa uguale per tutte le note fa sì che ogni nota sia divisa in un numero diverso di segmenti, ma devi tener conto
# di una cosa: più segmenti hai, e più vengono smussati tutti i tuoi picchi, sia armoniche che rumore.
# Dato che poi i picchi li leggeremo nello stesso modo per tutte le note, ha più senso che gli spettri abbiano tutti
# la stessa risoluzione. Per questo motivo, allora, non fissiamo la lunghezza dei segmenti, bensì ne fissiamo il numero totale,
# dato dal denominatore dell'espressione qui sopra.

# Definiamo la finestra con la width scelta:
gaussian_window = scipy.signal.windows.gaussian(int(width * rate), std = int(width * rate / 6))

# Ora usiamo welch:
frequencies, spectrum = welch(note, fs = rate, window = gaussian_window, nperseg = len(gaussian_window))
# Il primo parametro è l'array del segnale, il secondo il sampling rate.
# Il terzo parametro è la funzione finestra desiderata, che non a caso è da passare nello stesso formato in cui Scipy la genera.
# Il quarto parametro è la larghezza in indici di ciascun segmento, e per motivi teorici è opportuno dare la stessa della finestra.
# Se non diversamente specificato, il metodo welch crea segmenti con un overlap non nullo, che di default è di mezzo segmento.

# Il metodo restituisce già gli assi x,y della FFT, salvandoci parecchia fatica. Per convenzione ridefiniamo:
spectrum = 10 * np.log10(spectrum) # ossia ora sarà in decibel

# E grafichiamo il risultato:
plt.figure(figsize=(12,7))
plt.plot(frequencies, spectrum)
plt.xscale("log", base=10)
#plt.xscale("log", base=2)
plt.ylim(0, 120) # Nota che ai 0dB si ha già un silenzio molto profondo
plt.xlim(2**4, 2**14)
plt.ylabel("Spettro di potenza medio dei segmenti [dB]")
plt.xlabel("Frequenza [Hz]")
plt.grid(linestyle = ":")
# Nota che se l'asse x parte da 10Hz, non stiamo visualizzando i primissimi valori dei due array frequencies e spectrum.
# In particolare, per xlim inferiore di 2**4, il primo valore graficato è quello di indice 3, non quello di indice 0.
# In pratica, ci aspettiamo il sistema si comporti male nei primi 3 indici e quindi non ci interessano.

# Per distinguere i picchi, usiamo un altro metodo di Scipy, chiamato find_peaks:
peaks, _ = find_peaks(spectrum, prominence = 20)
# Il metodo distingue i picchi trovando gli indici per cui sia quello prima che quello dopo da valutati sono più bassi.
# Il parametro prominence serve a filtrare i picchi: vengono selezionati solo i picchi che sono alti almeno quanto la prominence
# rispetto ai due minimi locali vicini (identificati analogamente ai massimi).
index_of_max = np.argmax(spectrum[peaks])
previsional_frequency = frequencies[peaks[index_of_max]]
for peak in frequencies[peaks]:  
    plt.axvline(peak, color="g", linestyle="--")
plt.plot(previsional_frequency, spectrum[peaks[index_of_max]], marker = "o", linestyle = "None", color = "k")
plt.show()
print("\nPrima stima della fondamentale: {:.1f} Hz\n".format(previsional_frequency))
# Come prima stima, assumiamo che il picco più alto, tipicamente il primo, coincida con la armonica fondamentale.
# Out:
# Prima stima della fondamentale: 74.4 Hz

# %%
# Scriviamo una funzione che, data la lista di picchi trovata, sia in grado di stimare la fondamentale come il miglior MCD:
def f0_MCD(frequencies_of_peaks, highest_candidate):
    
    lowest_candidate = np.min(frequencies_of_peaks) / 3
    # Assumiamo di aver saltato al più la lettura dei primi due picchi
    
    candidates = np.arange(highest_candidate, lowest_candidate-0.1, -0.1)
    # Come candidati alla fondamentale prenderemo tutti i valori di mezzo con risoluzione 0.1Hz.
    # Nota che l'array di candidati è in ordine decrescente.
    
    lowest_residual = float("inf") # Sarà effettivamente inizializzato nella prima iterazione del ciclo
    best_f0 = highest_candidate # Giusto per riempire la variabile

    for f0 in candidates:
        ratios = frequencies_of_peaks / f0 # Per un buon candidato, questi rapporti saranno molto vicini a numeri interi
        integers = np.round(ratios) # Gli arrotondamenti veri e propri ci serviranno a quantificare la bontà del candidato
        
        if np.any(integers == 0):
            continue # continue interrompe e salta questa iterazione del ciclo for
        # Realisticamente non entreremo mai in questo check perché presume che il picco più alto sia molti picchi in là.
        # Il check comunque lo lasciamo perché serve a mantenere la consistenza della verifica che stiamo per svolgere.

        discrepancies = np.abs(ratios - integers)
        residual = np.sum(discrepancies)
        # Un candidato è buono quando i ratios sono vicini a numeri interi, quindi misuriamo il residual come la somma delle
        # discrepanze tra i ratio e gli effettivi numeri interi più vicini. Più piccolo è il residual, migliore è il candidato.

        # In prima approssimazione, la definizione del residual potrebbe anche andare bene così, ma decidiamo di aggiungere
        # una penalità nel caso in cui il candidato salti dei picchi:
        found_harmonics = len(np.unique(integers))
        max_harmonic = np.max(integers)
        missed_harmonics = max_harmonic - found_harmonics
        residual += missed_harmonics * 0.1 # dove 0.1 è il peso della punizione, regolabile.
        
        # Il valore del peso non è scelto a caso. Tipicamente, candidati grandi coprono tutti i picchi, ma con grandi discrepanze
        # che ne aumentano giustamente il residual. Per candidati piccoli, invece, è sistematico spiegare più facilmente i picchi,
        # ma altrettanto sistematicamente vengono saltati dei picchi, soprattutto all'inizio.
        # Vogliamo che ad esempio controllare la missing fundamental sia sempre punito in partenza (0.1 per il mancante picco 1),
        # ma meno rispetto a un candidato grande che spiega male un picco trovato (al massimo 0.5 ma più tipicamente intorno ai 0.3).
        # Senza questa punizione i candidati più bassi sarebbero super avvantaggiati!

        if residual < (lowest_residual * 0.95): # Se il margine è troppo piccolo allora non aggiorniamo
            lowest_residual = residual
            best_f0 = f0
            #print(f0, lowest_residual) # Per debugging
    
    return best_f0


# E usiamo subito la funzione:
frequencies_of_peaks = frequencies[peaks]
frequencies_of_peaks = frequencies_of_peaks[:10] # La prominence è bassina, quindi ad alte frequenza prende un sacco di rumore
fundamental = f0_MCD(frequencies_of_peaks, previsional_frequency)
print("\nSeconda stima della fondamentale: {:.1f} Hz\n".format(fundamental))
# Out:
# Seconda stima della fondamentale: 73.6 Hz

# %%
# Con una stima della fondamentale, buona o cattiva che sia, possiamo usarla per generare le armoniche "teoriche".
# Una volta generate, possiamo poi controllare quanto bene effettivamente coincidano con quelle "sperimentali".

estimated_harmonics = [fundamental * i for i in range(1,7)] # 6 elementi perché considereremo le prime 6 armoniche
measured_harmonics_frequency = []
measured_harmonics_power = []
neighborhood = 2 # Ci servirà quando un'armonica "sperimentale" sarà mancante e potremo affidarci solo a quella teorica.
# L'idea è che quando ad un picco teorico non corrisponde uno sperimentale allora considereremo come armonica la sola teorica,
# e l'altezza del picco sarà banalmente lo spettro valutato a quella frequenza. Tuttavia, per migliorare leggermente questi risultati,
# guardiamo un intorno di due indici a destra e sinistra e prendiamo il valore massimo dello spettro; magari il picco sperimentale c'è
# ma non siamo riusciti a leggerlo.
# Nota che per basse frequenze una differenza di un solo indice è già enorme, ecco perché questo valore è così basso.

# Se il picco teorico corrisponde (entro una tolleranza essere il 5% della frequenza) ad un picco sperimentale,
# allora come dato ci salviamo quello sperimentale. Senno, se il picco sperimentale manca, salviamo quello teorico:
for estimate in estimated_harmonics:
    index_closest_harmonic = np.argmin(np.abs(estimate - frequencies_of_peaks))
    closest_harmonic = frequencies_of_peaks[index_closest_harmonic]
    
    if abs(estimate - closest_harmonic) < (0.05 * closest_harmonic):
        measured_harmonics_frequency.append(closest_harmonic)
        index_target = np.argmin(np.abs(closest_harmonic - frequencies))
        measured_harmonics_power.append(spectrum[index_target])
    else:
        measured_harmonics_frequency.append(estimate)
        index_target = np.argmin(np.abs(estimate - frequencies))
        start = max(0, index_target - neighborhood)
        end = min(len(spectrum), index_target + neighborhood + 1)
        measured_harmonics_power.append(np.max(spectrum[start:end]))


plt.figure(figsize=(12,7))
plt.plot(frequencies, spectrum)
for estimate in estimated_harmonics:
    plt.axvline(estimate, color="r", linestyle="-")
for peak in frequencies_of_peaks:  
    plt.axvline(peak, color="g", linestyle="--")
plt.plot(measured_harmonics_frequency, measured_harmonics_power, marker = "o", linestyle = "None", color = "k")
plt.xscale("log", base=10)
#plt.xscale("log", base=2)
plt.ylim(0, 120)
plt.xlim(2**4, 2**14)
plt.ylabel("Spettro di potenza [dB]")
plt.xlabel("Frequenza [Hz]")
plt.grid(linestyle = ":")
plt.show()
# In verde come prima i picchi "sperimentali", ma adesso sono anche indicati in rosso i picchi "teorici".
# Con un punto nero indichiamo l'esatto valore selezionato come intensità di ciascuna armonica.
