# %%
import numpy as np
import scipy
from scipy.signal import find_peaks
from lib.readwav import *

# %% [markdown]
# # Estrapolazione e salvataggio delle armoniche nelle note prodotte dall'organo

# %%
# Funzione per applicazione la finestra gaussiana: 
def apply_window(rate, cut_note, sigma):
    sigma *= rate
    N = cut_note.shape[0]
    x = np.arange(N)
    center = 0.50 * N # Applicata al centro del segnale tagliato!
    window = np.exp(-0.5 * ((x - center) / sigma) ** 2)
    return cut_note * window

# %%
# Ciclo per estrapolazione su tutti i file:

fundamentals = [] # Array contenente le sole fondamentali per ciascun file
harmonics = [] # Lista contenente le armoniche: ogni riga è un file, ogni colonna un'armonica (inclusa la fondamentale)
power_spectra = [] # Lista contenente gli spettri valutati nelle frequenze delle armoniche
normalized_power_spectra = [] # Lista contenente sempre gli spettri valutati, ma ora anche divisi per la potenza della fondamentale

for file in range(280):
    print("È in corso l'analisi del file",file+1,"...")
    # Lettura file:
    filename = "./wav_files/note_{}.wav".format(file+1)
    rate, note = readwav(filename)
    note = note[:,0]
    time = np.linspace(0, note.shape[0], note.shape[0], endpoint = False) / rate
    first_15 = time[0] + 0.15 * (time[-1] - time[0])
    last_5 = time[0] + 0.95 * (time[-1] - time[0])
    cut = (time >= first_15) & (time <= last_5)
    note = note[cut]
   
    # Calcolo preventivo dello spettro medio:
    segment_size = int(rate * 0.05)
    hop_size = segment_size // 4
    number_of_segments = (len(note) - segment_size) // hop_size + 1
    segments_spectra = []
    for i in range(number_of_segments):
        start = i * hop_size
        end = start + segment_size
        segment = note[start:end]
        segment = apply_window(rate, segment, sigma = 0.15)
        power_spectrum = scipy.fft.rfft(segment)
        power_spectrum = np.abs(power_spectrum)**2
        segments_spectra.append(power_spectrum)
    averaged_spectrum = np.mean(segments_spectra, axis = 0)
    frequencies = scipy.fft.rfftfreq(segment.shape[0], d=1/rate)
    prom = 10**(np.floor(np.log10(averaged_spectrum[0]))+1) # occhio al +1 per prendere un picco molto alto
    previsional_peaks, _ = find_peaks(averaged_spectrum, prominence = prom)
    previsional_frequency = frequencies[previsional_peaks[0]]

    # Calcolo migliorato dello spettro medio:
    A = -0.03
    B = 0.40
    segment_size = int(rate * (A * np.log(previsional_frequency) + B) )
    hop_size = segment_size // 4
    number_of_segments = (len(note) - segment_size) // hop_size + 1
    segments_spectra = []
    for i in range(number_of_segments):
        start = i * hop_size
        end = start + segment_size
        segment = note[start:end]
        segment = apply_window(rate, segment, sigma = 0.15)
        power_spectrum = scipy.fft.rfft(segment)
        power_spectrum = np.abs(power_spectrum)**2
        segments_spectra.append(power_spectrum)
    averaged_spectrum = np.mean(segments_spectra, axis = 0)
    frequencies = scipy.fft.rfftfreq(segment.shape[0], d=1/rate)
    prom = 10**(np.floor(np.log10(averaged_spectrum[0]))) # senza il +1 (provare +0.5 o senza floor ??)
    corrected_peaks, _ = find_peaks(averaged_spectrum, prominence = prom)
    if len(corrected_peaks) < 6:
        prom = 10**(np.floor(np.log10(averaged_spectrum[0]))-1)
        corrected_peaks, _ = find_peaks(averaged_spectrum, prominence = prom)
    tolerance = previsional_frequency / 2
    frequencies_of_peaks = []
    for peak in corrected_peaks:
        aux = frequencies[peak]
        if all(abs(aux - f) > tolerance for f in frequencies_of_peaks):
            frequencies_of_peaks.append(aux)

    # Calcolo della fondamentale:
    peaks_distances = np.diff(frequencies_of_peaks)
    counts, bin_edges = np.histogram(peaks_distances, bins=20) 
    index_max = np.argmax(counts)
    distances_in_bin = peaks_distances[(peaks_distances >= bin_edges[index_max]) & (peaks_distances <= bin_edges[index_max + 1])]
    fundamental = np.mean(distances_in_bin)
    fundamentals.append(fundamental)   

    # Calcolo delle 5 armoniche successive:
    estimated_harmonics = [fundamental * i for i in range(1,7)]
    measured_harmonics_frequency = []
    measured_harmonics_power = []
    neighborhood = 5
    for estimate in estimated_harmonics:
        index_closest_harmonic = np.argmin(np.abs(estimate - frequencies_of_peaks))
        closest_harmonic = frequencies_of_peaks[index_closest_harmonic]
        if abs(estimate - closest_harmonic) < (0.05 * closest_harmonic):
            measured_harmonics_frequency.append(closest_harmonic)
            index_target = np.argmin(np.abs(closest_harmonic - frequencies))
            measured_harmonics_power.append(averaged_spectrum[index_target])
        else:
            measured_harmonics_frequency.append(estimate)
            index_target = np.argmin(np.abs(estimate - frequencies))
            start = max(0, index_target - neighborhood)
            end = min(len(averaged_spectrum), index_target + neighborhood + 1)
            measured_harmonics_power.append(np.max(averaged_spectrum[start:end]))
    harmonics.append(measured_harmonics_frequency)
    power_spectra.append(measured_harmonics_power)
    normalized_power_spectra.append(measured_harmonics_power / measured_harmonics_power[0])
print("\n\nFinito!\n")
# Out:
# È in corso l'analisi del file 1 ...
# È in corso l'analisi del file 2 ...
# È in corso l'analisi del file 3 ...
# È in corso l'analisi del file 4 ...
# È in corso l'analisi del file 5 ...
# È in corso l'analisi del file 6 ...
# È in corso l'analisi del file 7 ...
# È in corso l'analisi del file 8 ...
# È in corso l'analisi del file 9 ...
# È in corso l'analisi del file 10 ...
# È in corso l'analisi del file 11 ...
# È in corso l'analisi del file 12 ...
# È in corso l'analisi del file 13 ...
# È in corso l'analisi del file 14 ...
# È in corso l'analisi del file 15 ...
# È in corso l'analisi del file 16 ...
# È in corso l'analisi del file 17 ...
# È in corso l'analisi del file 18 ...
# È in corso l'analisi del file 19 ...
# È in corso l'analisi del file 20 ...
# È in corso l'analisi del file 21 ...
# È in corso l'analisi del file 22 ...
# È in corso l'analisi del file 23 ...
# È in corso l'analisi del file 24 ...
# È in corso l'analisi del file 25 ...
# È in corso l'analisi del file 26 ...
# È in corso l'analisi del file 27 ...
# È in corso l'analisi del file 28 ...
# È in corso l'analisi del file 29 ...
# È in corso l'analisi del file 30 ...
# È in corso l'analisi del file 31 ...
# È in corso l'analisi del file 32 ...
# È in corso l'analisi del file 33 ...
# È in corso l'analisi del file 34 ...
# È in corso l'analisi del file 35 ...
# È in corso l'analisi del file 36 ...
# È in corso l'analisi del file 37 ...
# È in corso l'analisi del file 206 ...
# È in corso l'analisi del file 207 ...
# È in corso l'analisi del file 208 ...
# È in corso l'analisi del file 209 ...
# È in corso l'analisi del file 210 ...
# È in corso l'analisi del file 211 ...
# È in corso l'analisi del file 212 ...
# È in corso l'analisi del file 213 ...
# È in corso l'analisi del file 214 ...
# È in corso l'analisi del file 215 ...
# È in corso l'analisi del file 216 ...
# È in corso l'analisi del file 217 ...
# È in corso l'analisi del file 218 ...
# È in corso l'analisi del file 219 ...
# È in corso l'analisi del file 220 ...
# È in corso l'analisi del file 221 ...
# È in corso l'analisi del file 222 ...
# È in corso l'analisi del file 223 ...
# È in corso l'analisi del file 224 ...
# È in corso l'analisi del file 225 ...
# È in corso l'analisi del file 226 ...
# È in corso l'analisi del file 227 ...
# È in corso l'analisi del file 228 ...
# È in corso l'analisi del file 229 ...
# È in corso l'analisi del file 230 ...
# È in corso l'analisi del file 231 ...
# È in corso l'analisi del file 232 ...
# È in corso l'analisi del file 233 ...
# È in corso l'analisi del file 234 ...
# È in corso l'analisi del file 235 ...
# È in corso l'analisi del file 236 ...
# È in corso l'analisi del file 237 ...
# È in corso l'analisi del file 238 ...
# È in corso l'analisi del file 239 ...
# È in corso l'analisi del file 240 ...
# È in corso l'analisi del file 241 ...
# È in corso l'analisi del file 242 ...
# È in corso l'analisi del file 243 ...
# È in corso l'analisi del file 244 ...
# È in corso l'analisi del file 245 ...
# È in corso l'analisi del file 246 ...
# È in corso l'analisi del file 247 ...
# È in corso l'analisi del file 248 ...
# È in corso l'analisi del file 249 ...
# È in corso l'analisi del file 250 ...
# È in corso l'analisi del file 251 ...
# È in corso l'analisi del file 252 ...
# È in corso l'analisi del file 253 ...
# È in corso l'analisi del file 254 ...
# È in corso l'analisi del file 255 ...
# È in corso l'analisi del file 256 ...
# È in corso l'analisi del file 257 ...
# È in corso l'analisi del file 258 ...
# È in corso l'analisi del file 259 ...
# È in corso l'analisi del file 260 ...
# È in corso l'analisi del file 261 ...
# È in corso l'analisi del file 262 ...
# È in corso l'analisi del file 263 ...
# È in corso l'analisi del file 264 ...
# È in corso l'analisi del file 265 ...
# È in corso l'analisi del file 266 ...
# È in corso l'analisi del file 267 ...
# È in corso l'analisi del file 268 ...
# È in corso l'analisi del file 269 ...
# È in corso l'analisi del file 270 ...
# È in corso l'analisi del file 271 ...
# È in corso l'analisi del file 272 ...
# È in corso l'analisi del file 273 ...
# È in corso l'analisi del file 274 ...
# È in corso l'analisi del file 275 ...
# È in corso l'analisi del file 276 ...
# È in corso l'analisi del file 277 ...
# È in corso l'analisi del file 278 ...
# È in corso l'analisi del file 279 ...
# È in corso l'analisi del file 280 ...

# %%
# Salvataggio su file esterni:
np.savetxt("fundamentals.csv", fundamentals, delimiter = ",")
np.savetxt("harmonics.csv", harmonics, delimiter = ",")
np.savetxt("power_spectra.csv", power_spectra, delimiter = ",")
np.savetxt("normalized_power_spectra.csv", normalized_power_spectra, delimiter = ",")
